# %%
import tensorflow as tf
import cv2
import os
import numpy as np
import time
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

# %%
emotion_labels = ['anger', 'contempt', 'disgust', 'fear', 'happy',
                  'neutral', 'sad', 'surprise', 'uncertain']
colors = [(0, 0, 255), (0, 255, 255), (0, 255, 0), 
                 (255, 0, 0), (255, 255, 0), (255, 255, 255), 
                 (0, 0, 0), (255, 0, 255), (128, 128, 128)]

# путь к файлу модели
file_path = "C:\\Users\\Admin\\ML. Средний уровень\\Cource\\skillbox-computer-vision-project\\tf_model_48_Adam06_64"

# %%
# # Вариант 1
# # Предсказания делаются непосредственно моделью через метод predict.
# class Fer_Model_Predict:
#     def __init__(self, model_path):
#         self.model = tf.keras.models.load_model(model_path)

#     def predict(self, image):
#         preprocessed = preprocess(image)
#         predictions = self.model.predict(preprocessed)          
#         return get_emotion(predictions)

# # out FPS 4-5

# Вариант 2
# используется не сама Keras-модель, а ее конвертированный в TFLite вариант для работы с interpreter.
class Fer_Model:
    def __init__(self, model_path):
        # Модель конвертируется в формат TensorFlow Lite с помощью TFLiteConverter.
        converter = tf.lite.TFLiteConverter.from_saved_model(model_path)
        tflite_model = converter.convert()
        with open('converted_model.tflite', 'wb') as f:
            f.write(tflite_model)
        # Создается объект Interpreter для интерпретации конвертированной модели.
        self.interpreter = tf.lite.Interpreter(model_path='converted_model.tflite')

    # Предсказания делаются уже не моделью напрямую, а через interpreter:
    def predict(self, image):
        preprocessed = preprocess(image).astype(np.float32)
        # Выделяются тензоры входа/выхода
        self.interpreter.allocate_tensors() 
        input_details = self.interpreter.get_input_details()
        output_details = self.interpreter.get_output_details()
        # Устанавливается входной тензор
        self.interpreter.set_tensor(input_details[0]['index'], preprocessed)
        self.interpreter.invoke() # Выполняется invoke interpreter'а
        # Получается выходной тензор
        predictions = self.interpreter.get_tensor(output_details[0]['index'])
        return get_emotion(predictions)
    
# out FPS 6-11

# %%
def detect_faces(frame):
    face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    grayscale_image = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(grayscale_image)
    return faces

def preprocess(image):
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    img_input = cv2.resize(img_gray, (48,48)) / 255.0
    img_input = np.expand_dims(img_input, axis=0)
    img_input = np.expand_dims(img_input, axis=-1)
    return img_input

def get_emotion(predictions):
    return emotion_labels[np.argmax(predictions)]

# %%
def plot_emotion_data(df):
  # Преобразование столбца 'Time'
  df['Time'] = pd.to_datetime(df['Time'])
  # График зависимости эмоции от времени
  fig, ax = plt.subplots(figsize=(10, 6))
  ax.plot(df['Time'], df['Emotion'], 'o-')
  # Настройка осей и заголовка  
  ax.set_xlabel('Time')
  ax.set_ylabel('Emotion')
  ax.set_title('Emotion over Time')

  # Круговая диаграмма распределения эмоций
  emotion_counts = df['Emotion'].value_counts()
  fig, ax = plt.subplots(figsize=(6, 6))
  patches, texts, autotexts = ax.pie(emotion_counts,  
                                     labels=emotion_counts.index, 
                                     autopct='%1.1f%%')
  ax.set_title('Distribution of Emotions')
  for text in texts:
      text.set_text('')
  ax.legend(patches, emotion_counts.index, 
            title='Emotions', 
            loc='center left', 
            bbox_to_anchor=(1, 0.5))
  plt.show()

# %%
cap = cv2.VideoCapture(0)
fps_count = 0
fps_time = time.time()
# проверка камеры
if not cap.isOpened():
    print("Не удалось открыть камеру")
else:
    print("Камера запущена")
    print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# проверка наличия файла модели
if os.path.exists(file_path):
    model = Fer_Model(file_path)
else:
    print("Файл модели не найден.")

df = pd.DataFrame(columns=['Time', 'Emotion'])

predicted = ""

while cap.isOpened():
    ret, frame = cap.read()
    if frame is not None:        
        cv2.imshow("facial emotion recognition", frame)
        faces = detect_faces(frame)
        # отрисовка рамок с предсказанием
        for i, (x, y, w, h) in enumerate(faces):
            if predicted in emotion_labels:
                cv2.rectangle(frame, (x, y), (x+w, y+h), 
                              colors[emotion_labels.index(predicted)], 2) 
                cv2.putText(frame, predicted, (x, y-10),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.9,
                           colors[emotion_labels.index(predicted)], 2)
            else:
                colors[emotion_labels.index('uncertain')], 2  # Default color if emotion is not in the list
            # Отображение количества обнаруженных лиц
            print("Найдено {} лицо/лиц".format(len(faces)))
            print("Массив faces: {}".format(faces))  
            # Отображение рамок
            cv2.imshow("facial emotion recognition", frame) 
            predicted = model.predict(frame)
            fps_count += 1
            current_time = time.time()

            df = df.append({'Time': datetime.now().strftime("%H:%M:%S.%f")[:-3], 'Emotion': predicted}, 
                           ignore_index=True)

            if current_time - fps_time >= 1:
                print("FPS: ", fps_count)
                fps_time = current_time
                fps_count = 0    
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
df.to_csv('emotions.csv')
# Out:
# Камера запущена
# 480.0
# Найдено 1 лицо/лиц
# Массив faces: [[223 122 246 246]]
# FPS:  1
# Найдено 1 лицо/лиц
# Массив faces: [[221 127 255 255]]
# Найдено 1 лицо/лиц
# Массив faces: [[215 132 267 267]]
# Найдено 1 лицо/лиц
# Массив faces: [[217 133 266 266]]
# Найдено 1 лицо/лиц
# Массив faces: [[213 134 266 266]]
# Найдено 1 лицо/лиц
# Массив faces: [[214 135 262 262]]
# Найдено 1 лицо/лиц
# Массив faces: [[215 132 271 271]]
# Найдено 1 лицо/лиц
# Массив faces: [[206 129 274 274]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 129 265 265]]
# FPS:  8
# Найдено 1 лицо/лиц
# Массив faces: [[218 128 260 260]]
# Найдено 1 лицо/лиц
# Массив faces: [[210 124 273 273]]
# Найдено 1 лицо/лиц
# Массив faces: [[216 130 266 266]]
# Найдено 1 лицо/лиц
# Массив faces: [[210 124 273 273]]
# FPS:  4
# Найдено 1 лицо/лиц
# Массив faces: [[210 124 273 273]]
# Найдено 1 лицо/лиц
# Массив faces: [[216 132 260 260]]
# Найдено 1 лицо/лиц
# Массив faces: [[213 123 276 276]]
# Найдено 1 лицо/лиц
# Массив faces: [[211 128 276 276]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 134 274 274]]
# FPS:  5
# Найдено 1 лицо/лиц
# Массив faces: [[208 134 276 276]]
# Найдено 1 лицо/лиц
# Массив faces: [[206 130 279 279]]
# Найдено 1 лицо/лиц
# Массив faces: [[207 134 274 274]]
# Найдено 1 лицо/лиц
# Массив faces: [[198 128 292 292]]
# Найдено 1 лицо/лиц
# Массив faces: [[205 127 287 287]]
# Найдено 1 лицо/лиц
# Массив faces: [[201 123 292 292]]
# FPS:  6
# Найдено 1 лицо/лиц
# Массив faces: [[210 130 281 281]]
# Найдено 1 лицо/лиц
# Массив faces: [[209 137 270 270]]
# Найдено 1 лицо/лиц
# Массив faces: [[228 136 215 215]]
# Найдено 1 лицо/лиц
# Массив faces: [[243 136 205 205]]
# FPS:  4
# Найдено 1 лицо/лиц
# Массив faces: [[251 143 192 192]]
# Найдено 1 лицо/лиц
# Массив faces: [[247 138 205 205]]
# Найдено 1 лицо/лиц
# Массив faces: [[247 141 193 193]]
# Найдено 1 лицо/лиц
# Массив faces: [[248 138 193 193]]
# Найдено 1 лицо/лиц
# Массив faces: [[236 144 181 181]]
# FPS:  5
# Найдено 1 лицо/лиц
# Массив faces: [[ 31 248  28  28]]
# Найдено 1 лицо/лиц
# Массив faces: [[159 260  68  68]]
# FPS:  2
# Найдено 1 лицо/лиц
# Массив faces: [[178 194 281 281]]
# Найдено 2 лицо/лиц
# Массив faces: [[181 144 296 296]
#  [505 422  53  53]]
# Найдено 2 лицо/лиц
# Массив faces: [[181 144 296 296]
#  [505 422  53  53]]
# Найдено 1 лицо/лиц
# Массив faces: [[160 101 289 289]]
# Найдено 1 лицо/лиц
# Массив faces: [[141  66 299 299]]
# Найдено 1 лицо/лиц
# Массив faces: [[154  78 283 283]]
# FPS:  6
# Найдено 1 лицо/лиц
# Массив faces: [[200 113 264 264]]
# Найдено 1 лицо/лиц
# Массив faces: [[194 135 251 251]]
# Найдено 1 лицо/лиц
# Массив faces: [[195 142 237 237]]
# Найдено 1 лицо/лиц
# Массив faces: [[206 154 233 233]]
# Найдено 1 лицо/лиц
# Массив faces: [[220 179 223 223]]
# Найдено 1 лицо/лиц
# Массив faces: [[219 194 221 221]]
# Найдено 1 лицо/лиц
# Массив faces: [[228 222 203 203]]
# Найдено 1 лицо/лиц
# Массив faces: [[231 233 201 201]]
# Найдено 1 лицо/лиц
# Массив faces: [[231 238 196 196]]
# FPS:  9
# Найдено 1 лицо/лиц
# Массив faces: [[230 242 195 195]]
# Найдено 1 лицо/лиц
# Массив faces: [[233 253 189 189]]
# Найдено 1 лицо/лиц
# Массив faces: [[235 252 189 189]]
# Найдено 1 лицо/лиц
# Массив faces: [[227 251 192 192]]
# Найдено 1 лицо/лиц
# Массив faces: [[234 279 185 185]]
# Найдено 1 лицо/лиц
# Массив faces: [[251 296 177 177]]
# Найдено 1 лицо/лиц
# Массив faces: [[230 282 198 198]]
# FPS:  7
# Найдено 1 лицо/лиц
# Массив faces: [[217 250 220 220]]
# Найдено 1 лицо/лиц
# Массив faces: [[201 214 238 238]]
# Найдено 1 лицо/лиц
# Массив faces: [[195 187 250 250]]
# Найдено 1 лицо/лиц
# Массив faces: [[195 152 267 267]]
# Найдено 1 лицо/лиц
# Массив faces: [[188 129 284 284]]
# Найдено 1 лицо/лиц
# Массив faces: [[182 116 298 298]]
# Найдено 1 лицо/лиц
# Массив faces: [[184 107 308 308]]
# Найдено 1 лицо/лиц
# Массив faces: [[189 105 309 309]]
# Найдено 1 лицо/лиц
# Массив faces: [[189 100 312 312]]
# Найдено 1 лицо/лиц
# Массив faces: [[182  88 322 322]]
# FPS:  10
# Найдено 1 лицо/лиц
# Массив faces: [[184  81 324 324]]
# Найдено 1 лицо/лиц
# Массив faces: [[176  70 337 337]]
# Найдено 1 лицо/лиц
# Массив faces: [[171  64 345 345]]
# Найдено 1 лицо/лиц
# Массив faces: [[170
]
# Найдено 1 лицо/лиц
# Массив faces: [[213 150 265 265]]
# Найдено 1 лицо/лиц
# Массив faces: [[211 148 267 267]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 148 266 266]]
# Найдено 1 лицо/лиц
# Массив faces: [[210 145 270 270]]
# Найдено 1 лицо/лиц
# Массив faces: [[209 143 271 271]]
# Найдено 1 лицо/лиц
# Массив faces: [[209 144 271 271]]
# Найдено 1 лицо/лиц
# Массив faces: [[213 146 265 265]]
# Найдено 1 лицо/лиц
# Массив faces: [[210 144 268 268]]
# FPS:  9
# Найдено 1 лицо/лиц
# Массив faces: [[212 145 266 266]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 143 268 268]]
# Найдено 1 лицо/лиц
# Массив faces: [[213 145 266 266]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 143 267 267]]
# Найдено 1 лицо/лиц
# Массив faces: [[213 143 267 267]]
# Найдено 1 лицо/лиц
# Массив faces: [[211 142 270 270]]
# Найдено 1 лицо/лиц
# Массив faces: [[210 141 270 270]]
# Найдено 1 лицо/лиц
# Массив faces: [[213 143 268 268]]
# Найдено 1 лицо/лиц
# Массив faces: [[211 144 267 267]]
# FPS:  9
# Найдено 1 лицо/лиц
# Массив faces: [[211 141 270 270]]
# Найдено 1 лицо/лиц
# Массив faces: [[213 142 267 267]]
# Найдено 1 лицо/лиц
# Массив faces: [[213 142 267 267]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 143 268 268]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 142 268 268]]
# Найдено 1 лицо/лиц
# Массив faces: [[213 143 267 267]]
# Найдено 1 лицо/лиц
# Массив faces: [[210 142 271 271]]
# Найдено 1 лицо/лиц
# Массив faces: [[214 145 265 265]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 145 270 270]]
# FPS:  9
# Найдено 1 лицо/лиц
# Массив faces: [[212 146 268 268]]
# Найдено 1 лицо/лиц
# Массив faces: [[210 146 271 271]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 151 270 270]]
# Найдено 1 лицо/лиц
# Массив faces: [[210 150 270 270]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 149 268 268]]
# Найдено 1 лицо/лиц
# Массив faces: [[212 149 268 268]]
# Найдено 1 лицо/лиц
# Массив faces: [[207 145 274 274]]
# Найдено 1 лицо/лиц
# Массив faces: [[207 142 277 277]]
# Найдено 1 лицо/лиц
# Массив faces: [[207 142 278 278]]
# FPS:  9
# Найдено 1 лицо/лиц
# Массив faces: [[207 142 276 276]]
# Найдено 1 лицо/лиц
# Массив faces: [[206 139 278 278]]
# Найдено 1 лицо/лиц
# Массив faces: [[202 136 283 283]]
# Найдено 1 лицо/лиц
# Массив faces: [[203 134 284 284]]
# Найдено 1 лицо/лиц
# Массив faces: [[200 134 285 285]]
# Найдено 1 лицо/лиц
# Массив faces: [[200 133 283 283]]
# Найдено 1 лицо/лиц
# Массив faces: [[202 134 281 281]]
# Найдено 1 лицо/лиц
# Массив faces: [[199 130 285 285]]
# Найдено 1 лицо/лиц
# Массив faces: [[198 131 286 286]]
# Найдено 1 лицо/лиц
# Массив faces: [[201 132 285 285]]
# FPS:  10
# Найдено 1 лицо/лиц
# Массив faces: [[200 134 282 282]]
# Найдено 1 лицо/лиц
# Массив faces: [[200 134 282 282]]
# Найдено 1 лицо/лиц
# Массив faces: [[202 136 281 281]]
# Найдено 1 лицо/лиц
# Массив faces: [[201 134 286 286]]
# Найдено 1 лицо/лиц
# Массив faces: [[197 131 292 292]]
# Найдено 1 лицо/лиц
# Массив faces: [[193 127 295 295]]
# Найдено 1 лицо/лиц
# Массив faces: [[193 127 295 295]]
# Найдено 1 лицо/лиц
# Массив faces: [[185 120 305 305]]
# Найдено 1 лицо/лиц
# Массив faces: [[179 112 313 313]]
# Найдено 1 лицо/лиц
# Массив faces: [[178 108 318 318]]
# FPS:  10
# Найдено 1 лицо/лиц
# Массив faces: [[181 104 321 321]]
# Найдено 1 лицо/лиц
# Массив faces: [[181 104 318 318]]
# Найдено 1 лицо/лиц
# Массив faces: [[183 107 315 315]]
# Найдено 1 лицо/лиц
# Массив faces: [
]
# FPS:  9
# Найдено 1 лицо/лиц
# Массив faces: [[182 104 311 311]]
# Найдено 1 лицо/лиц
# Массив faces: [[182 101 313 313]]
# Найдено 1 лицо/лиц
# Массив faces: [[183 101 310 310]]
# Найдено 1 лицо/лиц
# Массив faces: [[183 100 312 312]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  95 317 317]]
# Найдено 1 лицо/лиц
# Массив faces: [[183  98 313 313]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  96 316 316]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  97 315 315]]
# FPS:  8
# Найдено 1 лицо/лиц
# Массив faces: [[183  98 312 312]]
# Найдено 1 лицо/лиц
# Массив faces: [[184  99 312 312]]
# Найдено 1 лицо/лиц
# Массив faces: [[183  98 314 314]]
# Найдено 1 лицо/лиц
# Массив faces: [[184  97 312 312]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  97 315 315]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  98 315 315]]
# Найдено 1 лицо/лиц
# Массив faces: [[182  96 314 314]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  95 319 319]]
# FPS:  8
# Найдено 1 лицо/лиц
# Массив faces: [[181  96 317 317]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  98 316 316]]
# Найдено 1 лицо/лиц
# Массив faces: [[183 100 315 315]]
# Найдено 1 лицо/лиц
# Массив faces: [[182  98 316 316]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  99 314 314]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  96 318 318]]
# Найдено 1 лицо/лиц
# Массив faces: [[183  98 316 316]]
# Найдено 1 лицо/лиц
# Массив faces: [[182  96 318 318]]
# Найдено 1 лицо/лиц
# Массив faces: [[180  96 318 318]]
# FPS:  9
# Найдено 1 лицо/лиц
# Массив faces: [[181  97 315 315]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  96 315 315]]
# Найдено 1 лицо/лиц
# Массив faces: [[180  98 315 315]]
# Найдено 1 лицо/лиц
# Массив faces: [[183  98 317 317]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  94 321 321]]
# Найдено 1 лицо/лиц
# Массив faces: [[185  97 313 313]]
# Найдено 1 лицо/лиц
# Массив faces: [[181  95 317 317]]
# Найдено 1 лицо/лиц
# Массив faces: [[184  95 316 316]]
# Найдено 1 лицо/лиц
# Массив faces: [[182  96 318 318]]
# FPS:  9
# Найдено 1 лицо/лиц
# Массив faces: [[182  96 317 317]]
# Найдено 1 лицо/лиц
# Массив faces: [[179  97 319 319]]
# Найдено 1 лицо/лиц
# Массив faces: [[180 100 315 315]]
# Найдено 1 лицо/лиц
# Массив faces: [[179 102 312 312]]
# Найдено 1 лицо/лиц
# Массив faces: [[182  99 314 314]]
# Найдено 1 лицо/лиц
# Массив faces: [[182  81 325 325]]
# Найдено 1 лицо/лиц
# Массив faces: [[184  82 324 324]]
# Найдено 1 лицо/лиц
# Массив faces: [[179  94 323 323]]
# Найдено 1 лицо/лиц
# Массив faces: [[182 114 311 311]]
# FPS:  9
# Найдено 1 лицо/лиц
# Массив faces: [[182 117 309 309]]
# Найдено 1 лицо/лиц
# Массив faces: [[183 115 312 312]]
# Найдено 1 лицо/лиц
# Массив faces: [[183 115 312 312]]
# Найдено 1 лицо/лиц
# Массив faces: [[188 113 310 310]]
# Найдено 1 лицо/лиц
# Массив faces: [[187 110 311 311]]
# Найдено 1 лицо/лиц
# Массив faces: [[187 110 311 311]]
# Найдено 1 лицо/лиц
# Массив faces: [[188 109 312 312]]
# Найдено 1 лицо/лиц
# Массив faces: [[188 111 310 310]]
# Найдено 1 лицо/лиц
# Массив faces: [[191 111 306 306]]
# FPS:  9
# Найдено 1 лицо/лиц
# Массив faces: [[188 108 310 310]]

# %%
plot_emotion_data(df)
df
# Out:
#                        Time  Emotion
# 0   2023-12-01 00:11:41.496  neutral
# 1   2023-12-01 00:11:41.630  neutral
# 2   2023-12-01 00:11:41.834  neutral
# 3   2023-12-01 00:11:41.946  neutral
# 4   2023-12-01 00:11:42.036  neutral
# ..                      ...      ...
# 791 2023-12-01 00:13:23.826    anger
# 792 2023-12-01 00:13:23.956    anger
# 793 2023-12-01 00:13:24.074    anger
# 794 2023-12-01 00:13:24.176    anger
# 795 2023-12-01 00:13:24.280    anger
#
# [796 rows x 2 columns]
